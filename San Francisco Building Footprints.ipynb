# %%
#Import Libraries
from keplergl import KeplerGl
import pandas as pd
import geopandas

# %%
#Import dataset
df = pd.read_json('https://data.sfgov.org/resource/ynuv-fyni.json')

# %%
#Check dataset
df.head()
# Out:
#      sf16_bldgid  area_id         mblr             p2010_name  \
# 0  201006.000000        1    SF4570025      SanfranF_4606.flt
# 1  201006.000000        2  SM005050270     SanfranI_09417.flt
# 2  201006.000000        3    SF3794028  Sanfran_Orig_1330.flt
# 3  201006.000000        4    SF7295021                    NaN
# 4  201006.000001        5    SF9900015  Sanfran_Orig_0311.flt
#
#    p2010_zminn88ft  p2010_zmaxn88ft  gnd_cells50cm  gnd_mincm  gnd_maxcm  \
# 0          16.3249          66.2671         178250        507        704
# 1          81.7802         214.1874         144111       2515       3419
# 2          12.5027         102.5737         115295        164        507
# 3              NaN              NaN         107634       4346       5185
# 4           9.1163          57.9121         102761         81        422
#
#    gnd_rangecm  ...  hgt_majoritycm  hgt_minoritycm  hgt_mediancm  gnd_min_m  \
# ...

# %%
# Load a map, config  height, and load dataset
from keplergl import KeplerGl
map = KeplerGl(height=400, data={"df": df})
map
# Out:
# User Guide: https://github.com/keplergl/kepler.gl/blob/master/docs/keplergl-jupyter/user-guide.md
# KeplerGl(data={'df':        sf16_bldgid  area_id         mblr             p2010_name  \
# 0    201006.000000    …

# %%
#Preview of what the Kepler map looks like when embedded in Jupyter Notebook
from IPython.display import Image
Image("images/building-preview.png")

# %%
#Kepler configuration for Dataset 'df'
from IPython.display import Image
Image("images/3d-building-config.png")

# %%
map.save_to_html(file_name='Building.html') 
# if you wish to save your map as an .html you can run this command
# Then publish an interactive map on Github Pages ex. https://getcontrol.github.io/gis/Building.html
# Out:
# Map saved to Building.html!
